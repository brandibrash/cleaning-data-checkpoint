# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
https://github.com/brandibrash/eda-checkpoint.git
    
https://www.kaggle.com/vishalmane10/anime-dataset-2022

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

df = pd.read_csv('Anime.csv')
df.head(10)
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
# 5     6                                     Jujutsu Kaisen
# 6     7          Attack on Titan The Final Season: Part II
# 7     8                   Attack on Titan The Final Season
# 8     9  Demon Slayer: Kimetsu no Yaiba Movie - Mugen T...
# 9    10  Haikyuu!! Karasuno High School vs Shiratorizaw...
#
#                                        Japanese_name   Type  Episodes  \
# 0                      Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                            Fruits Basket the Final  TV         13.0
# 2                         The Founder of Diabolism 3  Web        12.0
# ...

# %%
df = df.rename(columns={'Tags': 'Genre_tags'})
df.head(5)
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# ...

# %%
df = df.drop(['Description', 'Release_season', 'Content_Warning', 'Related_Mange', 'Related_anime', 'End_year', 'staff'], axis=1)
df.head(5)

# %%
df.head(5)
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio                                         Genre_tags  \
# 0           ufotable  Action, Adventure, Fantasy, Shounen, Demons, H...
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Japanese_name', 'Type', 'Episodes', 'Studio',
#        'Genre_tags', 'Rating', 'Release_year', 'Voice_actors'],
#       dtype='object')

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
cols = df.columns[:30] 
colours = ['#000099', '#ffff00'] 
sb.heatmap(df[cols].isnull(), cmap=sb.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
med = df['Rating'].median()
print(med)
df['Rating'] = df['Rating'].fillna(med)
df.head(5)
# Out:
# 3.36
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
# 3     4                   Fullmetal Alchemist: Brotherhood
# 4     5                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio                                         Genre_tags  \
# 0           ufotable  Action, Adventure, Fantasy, Shounen, Demons, H...
# ...

# %%
cols = df.columns[:30] 
colours = ['#000099', '#ffff00'] 
sb.heatmap(df[cols].isnull(), cmap=sb.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
df = df.drop(['Japanese_name'], axis=1)
df.head(5)
# Out:
#    Rank                                               Name   Type  Episodes  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...  TV          NaN
# 1     2                     Fruits Basket the Final Season  TV         13.0
# 2     3                                    Mo Dao Zu Shi 3  Web        12.0
# 3     4                   Fullmetal Alchemist: Brotherhood  TV         64.0
# 4     5                Attack on Titan 3rd Season: Part II  TV         10.0
#
#               Studio                                         Genre_tags  \
# 0           ufotable  Action, Adventure, Fantasy, Shounen, Demons, H...
# 1  TMS Entertainment  Drama, Fantasy, Romance, Shoujo, Animal Transf...
# 2   B.C MAY PICTURES  Fantasy, Ancient China, Chinese Animation, Cul...
# 3              Bones  Action, Adventure, Drama, Fantasy, Mystery, Sh...
# 4         WIT Studio  Action, Fantasy, Horror, Shounen, Dark Fantasy...
#
#    Rating  Release_year                                       Voice_actors
# ...

# %% [markdown]
# Dropping Japanese Name Co;umn, not relevant to questions I am asking and there is a lot of missing data. I am not dropping episodes because although there is a lot of missing data I realized there may be missing data due to it being a movie rather than tv show.

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# 2. Did the process of cleaning your data give you new insights into your dataset?
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?

# %% [markdown]
# 1. I found lots of missing data and outliers but realized some were not neccessary but some are since they make sense to the data.
# 2. Cleaning did because it helped me nderstan that depending on what questions I am aking, not all data is necessary.
# 3. I would make notes of why I chose to keep some parts of data but not others.
